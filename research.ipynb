# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r'C:\Users\HP\Desktop\Python\Vs_Python\Data analysis\Kaggle_Competition\artifacts\data_extraction\sales_2024_q1.csv')

# %%
df['unit'].unique()
# Out:
# array(['oz', 'lb', 'each', 'qt', 'ct', 'gal'], dtype=object)
