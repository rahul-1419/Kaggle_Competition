# %%
import gdown

file_id='1z7qTQKSuyiA9bTNUUVyh-gitMYSmgrwF'
url = f"https://drive.google.com/uc?id={file_id}"

gdown.download(url,'../data/data.zip',quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1z7qTQKSuyiA9bTNUUVyh-gitMYSmgrwF
# From (redirected): https://drive.google.com/uc?id=1z7qTQKSuyiA9bTNUUVyh-gitMYSmgrwF&confirm=t&uuid=20f3f989-c01f-431f-b5c7-5e9fce107f67
# To: c:\Users\HP\Desktop\Python\Vs_Python\Data analysis\Kaggle_Competition\data\data.zip
# 100%|██████████| 34.1M/34.1M [00:52<00:00, 644kB/s]
# '../data/data.zip'

# %%
import zipfile

with zipfile.ZipFile('../data/data.zip', 'r') as zip_ref:
    zip_ref.extractall('../data/raw')
